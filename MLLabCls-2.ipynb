# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
import os
cwd=os.getcwd()
print(cwd)
# Out:
# C:\Users\HP

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[0]
# Out:
# Pregnancies                   6.000
# Glucose                     148.000
# BloodPressure                72.000
# SkinThickness                35.000
# Insulin                       0.000
# BMI                          33.600
# DiabetesPedigreeFunction      0.627
# Age                          50.000
# Outcome                       1.000
# Name: 0, dtype: float64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.iloc[0:2,[2,5]]
# Out:
#    BloodPressure   BMI
# 0             72  33.6
# 1             66  26.6

# %%
df.loc[0:2,['Glucose','Age']]
# Out:
#    Glucose  Age
# 0      148   50
# 1       85   31
# 2      183   32

# %%
x=df.iloc[:-1]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
read=df.dropna(axis=0,how='any')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 read=df.dropna(axis=0,how='any')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
import os
cwd=os.getcwd()
print(cwd)
# Out:
# C:\Users\HP

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
read=df.dropna(axis=0,how='any')

# %%
read
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
read.shape
# Out:
# (768, 9)

# %%
read1=df.dropna(axis=0,how='all')

# %%
read1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
read1.shape
# Out:
# (768, 9)

# %%
read2=df.dropna(axis=1,how='any')

# %%
read2.shape
# Out:
# (768, 9)

# %%
read2=df.dropna(axis=1,how='any')

# %%
read2.shape
# Out:
# (768, 9)

# %%
df=pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome    NA
# 0                       0.627   50        1  Null
# ...

# %%
read2=df.dropna(axis=1,how='any')

# %%
read2.shape
# Out:
# (768, 9)

# %%
read2=df.dropna(axis=0,how='any')

# %%
read2.shape
# Out:
# (3, 10)

# %%
null_mask=df.isnull()

# %%
null_mask
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome     NA
# ...

# %%
print(null_mask)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome     NA
# ...

# %%
null_mask=df.isnull().any(axis=1)

# %%
print(null_mask)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767     True
# Length: 768, dtype: bool

# %%
null_mask=df.isnull().any(axis=0)

# %%
print(null_mask)
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# NA                           True
# dtype: bool

# %%
null_rows=df[null_mask]
print(null_rows)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome   NA
# 3                       0.167   21        0  NaN
# ...

# %%
df=pd.read_csv('Student.csv')

# %%
df
# Out:
#     Name  SRN  Mark1  Mark2  Mark3 Target
# 0   Ajay   11   88.0     99     70  <=50k
# 1  Kiran   22   98.0     11     71   >50k
# 2  Peter   33  100.0     23     67  <=50k
# 3   Rama   44    NaN     23     78    >50

# %%
x=df.iloc[:,:-1]
y=df.loc[:,'Target']

# %%
x
# Out:
#     Name  SRN  Mark1  Mark2  Mark3
# 0   Ajay   11   88.0     99     70
# 1  Kiran   22   98.0     11     71
# 2  Peter   33  100.0     23     67
# 3   Rama   44    NaN     23     78

# %%
y
# Out:
# 0    <=50k
# 1     >50k
# 2    <=50k
# 3      >50
# Name: Target, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
y= LabelEncoder().fit_transform(y)
y=pd.DataFrame(y)
y.head()
# Out:
#    0
# 0  0
# 1  2
# 2  0
# 3  1

# %%
numeric_features=x.select_dtypes('number')
categorical_features=x.select_dtypes('object')
categorical_features
# Out:
#     Name
# 0   Ajay
# 1  Kiran
# 2  Peter
# 3   Rama

# %%
converted_categorical_features=pd.get_dummies(categorical_features)
converted_categorical_features.shape
# Out:
# (4, 4)

# %%
converted_categorical_features
# Out:
#    Name_Ajay  Name_Kiran  Name_Peter  Name_Rama
# 0       True       False       False      False
# 1      False        True       False      False
# 2      False       False        True      False
# 3      False       False       False       True

# %%
from sklearn.model_selection import train_test_split
import sklearn.metrics as sn
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#     Name  SRN  Mark1  Mark2  Mark3
# 3   Rama   44    NaN     23     78
# 1  Kiran   22   98.0     11     71

# %%
y_train
# Out:
#    0
# 3  1
# 1  2

# %%
x_test
# Out:
#     Name  SRN  Mark1  Mark2  Mark3
# 0   Ajay   11   88.0     99     70
# 2  Peter   33  100.0     23     67

# %%
y_test
# Out:
#    0
# 0  0
# 2  0
